# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import time
import datetime
import math
#jupyter notebook --notebook-dir=C:\xampp\htdocs\NEUROTRON

# %% [markdown]
# ![](plots/plot1741576899.svg)

# %%
# Get the list of all files and directories
path = "C://xampp//htdocs//NEUROTRON//plots"
dir_list = os.listdir(path)
dir_list
# Out:
# ['plot1741738322.412.svg',
#  'plot1741738329.291.svg',
#  'plot1741738335.991.svg',
#  'plot1741738426.611.svg',
#  'plot1741738465.679.svg',
#  'plot1741738515.784.svg']

# %%
datalist = []
for filename in dir_list:
    if(filename[-4:] == '.svg'):
        file = open('plots//' + filename, "r")
        rawdata = file.read()
        file.close()
        y = json.loads(rawdata.split("<json>")[1].split("</json>")[0])
        datalist.append(y)

# %%
t0 = datalist[len(datalist)-1]["starttime"]
for dataset in datalist:
    tprime = dataset["starttime"] - t0
    plt.plot(np.array(dataset["timeseconds"]) - tprime,dataset["p1"],color="red")
    plt.plot(np.array(dataset["timeseconds"]) - tprime,dataset["p2"],color="green")
    plt.plot(np.array(dataset["timeseconds"]) - tprime,dataset["p3"],color="blue")
    plt.plot(np.array(dataset["timeseconds"]) - tprime,dataset["p4"],color="purple")

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-53079012ea51> in <module>
# ----> 1 plt.plot(np.array(datalist[len(datalist) - 6]["timeseconds"]) -datalist[len(datalist) - 6]["starttime"] +  datalist[len(datalist) - 0]["starttime"],datalist[len(datalist) - 6]["p1"],color="red")
#
# IndexError: list index out of range

# %%
plt.plot(datalist[len(datalist) - 6]["timeseconds"],datalist[len(datalist) - 6]["p1"],color="red")
plt.plot(datalist[len(datalist) - 6]["timeseconds"],datalist[len(datalist) - 6]["p2"],color="green")
plt.plot(datalist[len(datalist) - 6]["timeseconds"],datalist[len(datalist) - 6]["p3"],color="blue")
plt.plot(datalist[len(datalist) - 6]["timeseconds"],datalist[len(datalist) - 6]["p4"],color="purple")
plt.plot(datalist[len(datalist) - 4]["timeseconds"],datalist[len(datalist) - 4]["p1"],color="red")
plt.plot(datalist[len(datalist) - 4]["timeseconds"],datalist[len(datalist) - 4]["p2"],color="green")
plt.plot(datalist[len(datalist) - 4]["timeseconds"],datalist[len(datalist) - 4]["p3"],color="blue")
plt.plot(datalist[len(datalist) - 4]["timeseconds"],datalist[len(datalist) - 4]["p4"],color="purple")

plt.plot(datalist[len(datalist) - 1]["timeseconds"],datalist[len(datalist) - 1]["p1"],color="red")
plt.plot(datalist[len(datalist) - 1]["timeseconds"],datalist[len(datalist) - 1]["p2"],color="green")
plt.plot(datalist[len(datalist) - 1]["timeseconds"],datalist[len(datalist) - 1]["p3"],color="blue")
plt.plot(datalist[len(datalist) - 1]["timeseconds"],datalist[len(datalist) - 1]["p4"],color="purple")

# %%
datalist[len(datalist) - 2]["timeseconds"]
# Out:
# [0.03000020980834961,
#  0.06300020217895508,
#  0.09600019454956055,
#  0.13000011444091797,
#  0.16300010681152344,
#  0.1960000991821289,
#  0.23000001907348633,
#  0.26400017738342285,
#  0.29600000381469727,
#  0.32899999618530273,
#  0.36300015449523926,
#  0.3960001468658447,
#  0.4290001392364502,
#  0.46400022506713867,
#  0.4960000514984131,
#  0.5300002098083496,
#  0.5630002021789551,
#  0.5960001945495605,
#  0.629000186920166,
#  0.6630001068115234,
#  0.6970000267028809,
#  0.7300000190734863,
#  0.7640001773834229,
#  0.7970001697540283,
#  0.8300001621246338,
#  0.8630001544952393,
#  0.8960001468658447,
#  0.9310002326965332,
#  0.9630000591278076,
#  0.9970002174377441,
#  1.0290000438690186,
#  1.063000202178955,
#  1.0960001945495605,
#  1.130000114440918,
#  1.1630001068115234,
#  1.1970000267028809,
#  1.2290000915527344,
#  1.2630000114440918,
#  1.2950000762939453,
#  1.3300001621246338,
#  1.3630001544952393,
#  1.3960001468658447,
#  1.4300000667572021,
# ...

# %%
f = 6.83e9
Gamma1 = 8.2e6
Gamma2 = 5.7e6
h = 6.63e-34
p2omega2 = 2*Gamma1/(h*f)
deltaf = np.linspace(-60e6,60e6, num=1000)
deltaomega =2*np.pi*deltaf


powerdbm = -140
powerwatts = 1e-3*10**(powerdbm/10)
omegasquared = p2omega2*powerwatts
r0 = 0.92
r = r0*(1 + 1j*deltaf*2*np.pi/Gamma2)/(1 + (deltaf*2*np.pi/Gamma2)**2 + omegasquared/(Gamma1*Gamma2))
plt.plot(deltaf,np.imag(r),deltaf,np.real(r))
#plt.legend(['path3','path4','path6','path3','path4','path6'])
plt.grid()
plt.xlabel('Frequency [GHz]', fontsize = 16)
plt.ylabel('$|S_{11}|^2$ or $|S_{22}|^2$ or $|S_{33}|^2$ or $|S_{44}|^2$\n[dB]', fontsize = 16)
#plt.ylim((-70,0))
#plt.xlim((1,8))
#plt.title('path1')
ax = plt.gca()
ax.tick_params(axis='x', labelsize=16)  # X-axis tick labels
ax.tick_params(axis='y', labelsize=16)  # X-axis tick labels

# %%
powersweep = np.linspace(-150,-100,10)
legendlist = []
for powerdbm in powersweep:
    powerwatts = 1e-3*10**(powerdbm/10)
    omegasquared = p2omega2*powerwatts
    r0 = 0.92
    r = r0*(1 + 1j*deltaf*2*np.pi/Gamma2)/(1 + (deltaf*2*np.pi/Gamma2)**2 + omegasquared/(Gamma1*Gamma2))
    plt.plot(deltaf/1e6,np.real(r), linewidth=4)
    legendlist.append('P = ' + str(int(np.round(powerdbm))) + " dBm")
    
plt.xlim((-15,15))
plt.legend(legendlist,loc='upper left')
plt.xlabel('$\delta\omega/2\pi [MHz]$')
plt.ylabel('Re[r]')
plt.grid()
